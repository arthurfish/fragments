// %% [markdown]
// ## CPS1231 Homework 6: Math functions, Characters, Strings

// %% [markdown]
// ### <span style="color:#a50e30;">Practice 1: </span>

// %% [markdown]
// (*Random points on a circle*) Write a program that generates three random points on a circle centered at (0, 0) with radius 40 and displays three angles in a triangle formed by these three points, as shown in Figure 4.4a. (Hint: Generate a random angle a in radians between 0 and 2π, as shown in Figure 4.4b and the point determined by this angle is (*r<sup>x</sup>cos (a)*, *r<sup>x</sup>sin (a)*).)

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// (Make sure to run the cell and preserve the output)

// %% [markdown]
// ***Write Your Code in Cell Below:***

// %%
//Purpose: Calculate the current problem by some steps
//and the output the result. With some information promt
//and some variable defined then initialized.
//
//public static class AngleCalculator

//Step 1:
//Inport the tools that JDK prepared
//and inititalize the needed variables
//or some system refference for the above usage.
import static java.lang.Math.*;
import static java.lang.System.out;

class Point{
    public double x;
    public double y;

    public Point(double x, double y){
        this.x = x;
        this.y = y;
    }
}

var vertices = new Point[3];



//Step 2:
//Do some procedure with the data, make the quantities
//fit the require of the problem, and make sure there
//are no memory leak or logic error.

for(int i = 0; i < 3; i++){
    var theta = random() * 2 * PI;
    vertices[i] = new Point(40*cos(theta), 40*sin(theta));
}

double getDistance(int u, int v){
    var x1 = vertices[u].x;
    var y1 = vertices[u].y;
    var x2 = vertices[v].x;
    var y2 = vertices[v].y;
    return sqrt(pow(x1-x2, 2) + pow(y1-y2, 2));
}

for(var vertex: vertices){
    out.printf("(%f, %f)\n", vertex.x, vertex.y);
}




//Step 3:
//Since we get the needed result, then we output it
//to the user to make all the procedure done. A whole
//algorithm not only included input and procedure,
//but also output.
for (int[] state: new int[][]{{0, 1, 2}, {1, 2, 0}, {2, 0, 1}}){
    var A = state[0];
    var B = state[1];
    var C = state[2];
    var a = getDistance(B, C);
    var b = getDistance(A, C);
    var c = getDistance(A, B);
    
    var theta = acos((a*a + b*b - c*c)/(2*a*b));
    out.println(theta);

}
// Out:
// (30.642624, -25.710496)
// (-36.820035, 15.629620)
// (31.335198, 24.861725)
// 1.4224648885111715
// 1.034722878715286
// 0.6844048863633356

// %% [markdown]
// ### <span style="color:#a50e30;">Practice 2: </span>

// %% [markdown]
// (*Days of a month*) Write a program that prompts the user to enter the year and the first three letters of a month name (with the first letter in uppercase) and displays the number of days in the month. If the input for month is incorrect, display a message as presented in the following sample runs:

// %% [markdown]
// ***Write Your Code in Cell Below:***

// %%
//Purpose: Calculate the current problem by some steps
//and the output the result. With some information promt
//and some variable defined then initialized.
//
//public static class DateNumberCalculator

//Step 1:
//Inport the tools that JDK prepared
//and inititalize the needed variables
//or some system refference for the above usage.
import java.util.Calendar;
import java.text.SimpleDateFormat;
import java.util.Scanner;


//Step 2:
//Do some procedure with the data, make the quantities
//fit the require of the problem, and make sure there
//are no memory leak or logic error.
System.out.println("Enter the year and the first three letters of a month name (with the first letter in uppercase): ");
var calendar = Calendar.getInstance();
var formatter = new SimpleDateFormat("yyyy MMM dd", Locale.ENGLISH);
calendar.setTime(formatter.parse((new Scanner(System.in)).nextLine() + " 1"));


//Step 3:
//Since we get the needed result, then we output it
//to the user to make all the procedure done. A whole
//algorithm not only included input and procedure,
//but also output.
System.out.println(calendar.getActualMaximum(Calendar.DAY_OF_MONTH));
// Out:
// Enter the year and the first three letters of a month name (with the first letter in uppercase):
// ---------------------------------------------------------------------------
// java.text.ParseException: Unparseable date: "I2 1"
// 	at java.base/java.text.DateFormat.parse(DateFormat.java:399)
// 	at .(#26:1)

// %% [markdown]
// ### <span style="color:#a50e30;">Practice 3: </span>

// %% [markdown]
// (*Student major and status*) Write a program that prompts the user to enter two
// characters and displays the major and status represented in the characters. The first
// character indicates the major and the second is number character 1, 2, 3, 4, which
// indicates whether a student is a freshman, sophomore, junior, or senior. Suppose
// the following characters are used to denote the majors:
//
// * I: Information Management
// * C: Computer Science
// * A: Accounting
//
// Here is a sample run:

// %% [markdown]
// ***Write Your Code in Cell Below:***

// %%
//Purpose: Calculate the current problem by some steps
//and the output the result. With some information promt
//and some variable defined then initialized.
//
//public static class SymbolCalculator

//Step 1:
//Inport the tools that JDK prepared
//and inititalize the needed variables
//or some system refference for the above usage.
System.out.println("Enter two characters and displays the major and status represented in the characters: ");



//Step 2:
//Do some procedure with the data, make the quantities
//fit the require of the problem, and make sure there
//are no memory leak or logic error.
var twoChar = (new Scanner(System.in)).nextLine();


//Step 3:
//Since we get the needed result, then we output it
//to the user to make all the procedure done. A whole
//algorithm not only included input and procedure,
//but also output.
System.out.println(Map.of('I', "Information Management", 'C', "Computer Science", 'A', "Accounting").get(twoChar.charAt(0)));
System.out.println(Map.of('1', "freshman", '2', "sophomore", '3', "junior", '4', "senior").get(twoChar.charAt(1)));
// Out:
// Enter two characters and displays the major and status represented in the characters:
// Information Management
// sophomore

// %% [markdown]
// ### <span style="color:#a50e30;">Practice 4: </span>

// %% [markdown]
// (*Enter three countries*) Write a program that prompts the user to enter three countries
// and displays them in descending order. Here is a sample run:

// %%
//Purpose: Calculate the current problem by some steps
//and the output the result. With some information promt
//and some variable defined then initialized.
//
//public static class ContriesCalculator

//Step 1:
//Inport the tools that JDK prepared
//and inititalize the needed variables
//or some system refference for the above usage.

var scanner = new Scanner(System.in);
var contries = new String[] {scanner.next(), scanner.next(), scanner.next()};

//Step 2:
//Do some procedure with the data, make the quantities
//fit the require of the problem, and make sure there
//are no memory leak or logic error.
Arrays.sort(contries, Collections.reverseOrder());


//Step 3:
//Since we get the needed result, then we output it
//to the user to make all the procedure done. A whole
//algorithm not only included input and procedure,
//but also output.
System.out.printf("%s %s %s", contries[0], contries[1], contries[2]);
// Out:
// f d a
// java.io.PrintStream@4f7522e6

// %% [markdown]
// ***Write Your Code in Cell Below:***

// %% [markdown]
// For submission, you will need to upload the <em> Jupyter Notebook</em> file to Blackboard for grading. Make sure rename the file using your ***Chinese Name in Pinyin*** and ***Student ID***.

// %% [markdown]
// ------------------------------------***End of Homework 5***---------------------------------------------------------------------------
