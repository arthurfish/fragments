# %%
import pandas as pd
import numpy as np
import json

# %%
d1 = pd.read_csv("MovieGenre.csv", encoding="latin1")
d1
# Out:
#        imdbId                           Imdb Link  \
# 0      114709  http://www.imdb.com/title/tt114709
# 1      113497  http://www.imdb.com/title/tt113497
# 2      113228  http://www.imdb.com/title/tt113228
# 3      114885  http://www.imdb.com/title/tt114885
# 4      113041  http://www.imdb.com/title/tt113041
# ...       ...                                 ...
# 40103   83168   http://www.imdb.com/title/tt83168
# 40104   82875   http://www.imdb.com/title/tt82875
# 40105  815258  http://www.imdb.com/title/tt815258
# 40106   79142   http://www.imdb.com/title/tt79142
# 40107   70710   http://www.imdb.com/title/tt70710
#
#                                     Title  IMDB Score  \
# 0                        Toy Story (1995)         8.3
# 1                          Jumanji (1995)         6.9
# 2                 Grumpier Old Men (1995)         6.6
# 3                Waiting to Exhale (1995)         5.7
# 4      Father of the Bride Part II (1995)         5.9
# ...

# %%
d1.Title = d1.Title.apply(lambda x: x.split('(')[0].strip())

# %%
d1
# Out:
#        imdbId                           Imdb Link  \
# 0      114709  http://www.imdb.com/title/tt114709
# 1      113497  http://www.imdb.com/title/tt113497
# 2      113228  http://www.imdb.com/title/tt113228
# 3      114885  http://www.imdb.com/title/tt114885
# 4      113041  http://www.imdb.com/title/tt113041
# ...       ...                                 ...
# 40103   83168   http://www.imdb.com/title/tt83168
# 40104   82875   http://www.imdb.com/title/tt82875
# 40105  815258  http://www.imdb.com/title/tt815258
# 40106   79142   http://www.imdb.com/title/tt79142
# 40107   70710   http://www.imdb.com/title/tt70710
#
#                              Title  IMDB Score                       Genre  \
# 0                        Toy Story         8.3  Animation|Adventure|Comedy
# 1                          Jumanji         6.9     Action|Adventure|Family
# 2                 Grumpier Old Men         6.6              Comedy|Romance
# ...

# %%
d2 = pd.read_csv("tmdb_5000_movies.csv")
d2.sample()
# Out:
#       budget                                             genres homepage  \
# 2915       0  [{"id": 12, "name": "Adventure"}, {"id": 80, "...      NaN
#
#           id                                           keywords  \
# 2915  206563  [{"id": 983, "name": "brazilian"}, {"id": 8029...
#
#      original_language original_title  \
# 2915                pt          Trash
#
#                                                overview  popularity  \
# 2915  Set in Brazil, three kids who make a discovery...   14.637357
#
#                                    production_companies  \
# 2915  [{"name": "O2 Filmes", "id": 345}, {"name": "W...
#
#                                    production_countries release_date  revenue  \
# 2915  [{"iso_3166_1": "BR", "name": "Brazil"}, {"iso...   2014-10-09        0
#
#       runtime                                   spoken_languages    status  \
# 2915    112.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
# ...

# %%
s = set(d2.title.tolist()) & set(d1.Title.tolist())

# %%
len(s)
# Out:
# 4324

# %%
len(d2.title.tolist())
# Out:
# 4803

# %%
d3 = pd.read_csv(
    'wiki_movie_plots_deduped_with_summaries.csv')
d3.sample()
# Out:
#        Release Year   Title Origin/Ethnicity              Director  \
# 28664          2017  Aadu 2        Malayalam  Midhun Manuel Thomas
#
#                                                     Cast    Genre  \
# 28664  Jayasurya, Dharmajan Bolgatty, Saiju Kurup, Vi...  unknown
#
#                                   Wiki Page  \
# 28664  https://en.wikipedia.org/wiki/Aadu_2
#
#                                                     Plot  \
# 28664  Shaji goes on with life in his regular heroism...
#
#                                              PlotSummary
# 28664  Shaji goes on with life in his regular heroism...

# %%
m1 = pd.merge(d3.Title, d2.title, how='inner')
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# C:\Users\ARTHUR~1\AppData\Local\Temp/ipykernel_18236/3443040483.py in <module>
# ----> 1 m1 = pd.merge(d3.Title, d2.title, how='inner')
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     104     validate: str | None = None,
#     105 ) -> DataFrame:
# --> 106     op = _MergeOperation(
#     107         left,
#     108         right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     679             warnings.warn(msg, FutureWarning, stacklevel=3)
#     680
# --> 681         self._validate_specification()
#     682
#     683         cross_col = None
# ...

# %%
d3.Title = d3.Title.apply(lambda x: x.strip().lower())
d2.title = d2.title.apply(lambda x: x.strip().lower())

# %%
s2 = set(d3.Title) & set(d2.title)

# %%
len(s2)
# Out:
# 3666
